# %%
import pandas as pd

# %%
dataset = pd.read_csv('data_samarth.csv', index_col = [0])

# %%
dataset
# Out:
#              PMID                                                 TI  \
# 693288   27917950  Utility of real-time prospective motion correc...
# 693289   27917915  Blood hsa-miR-122-5p and hsa-miR-885-5p levels...
# 693291   27917463  Decision-Making Regarding Mammography Screenin...
# 693292   27917457  Patient-reported outcomes (PROs) after total e...
# 693298   27917367  The Role of Interaction Model in Simulation of...
# ...           ...                                                ...
# 1385557  14691541  Linkage of osteoporosis to chromosome 20p12 an...
# 1385576  14551916  Candidate gene association study in type 2 dia...
# 1385584  33187395    Routine Vaccination Coverage - Worldwide, 2019.
# 1385585   8548215  Human immunodeficiency virus and acquired immu...
# 1385589   2143929    Diagnosis and treatment of epidural metastases.
#
#                                                         AB  \
# 693288   PROspective MOtion correction (PROMO) can prev...
# ...

# %%
import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_sm")

# %%
import nltk
from nltk.tokenize import sent_tokenize

# %%
def find_identities(para):
    ents = []
    for ent in nlp(para).ents:
        ents.append(ent.text)
    return ent

# %%
dataset['Disclosure'] = dataset['COIS'].apply(find_identities)
