# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.24.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-large-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-large-NER")
# Out:
# Downloading:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/data_research/Replaced_Full_Data.csv', index_col = [0])

# %%
df
# Out:
#                 PMID                                                 TI  \
# Unnamed: 0
# 6           36057537  Anticoagulation and Subclinical Valve Thrombos...
# 8           36057535  Five-Year Follow-Up Images of a Balloon Expand...
# 13          36057529  Survivors of Sudden Cardiac Arrest Presenting ...
# 15          36057526  Predictive performance and clinical applicatio...
# 16          36057525  Telomere biology disorders: time for moving to...
# ...              ...                                                ...
# 1385557     14691541  Linkage of osteoporosis to chromosome 20p12 an...
# 1385576     14551916  Candidate gene association study in type 2 dia...
# 1385584     33187395    Routine Vaccination Coverage - Worldwide, 2019.
# 1385585      8548215  Human immunodeficiency virus and acquired immu...
# 1385589      2143929    Diagnosis and treatment of epidural metastases.
#
#                                                            AB  \
# Unnamed: 0
# 6                                                         NaN
# 8                                                         NaN
# 13          BACKGROUND: The proportion of sudden cardiac a...
# 15          BACKGROUND: The SARS-CoV-2 pandemic is a world...
# 16          Telomere biology disorders (TBDs) are a group ...
# ...                                                       ...
# 1385557     Osteoporotic fractures are a major cause of mo...
# 1385576     Type 2 diabetes is an increasingly common, ser...
# 1385584     Endorsed by the World Health Assembly in 2020,...
# 1385585     Advances in medical management have enhanced b...
# 1385589     Epidural metastases are a common complication ...
#
#                                                            AD  \
# Unnamed: 0
# 6           Zena and Michael A. Wiener Cardiovascular Inst...
# 8           Department of Cardiology, New Tokyo Hospital, ...
# 13          Center for Cardiac Arrest Prevention, Departme...
# 15          Non-Profit Research Institute Alliance for the...
# 16          Department of Medicine, Washington University ...
# ...                                                       ...
# 1385557     deCODE Genetics, Reykjavik, Iceland. unnur.sty...
# 1385576     Incyte, Palo Alto, California, USA. ib1@sanger...
# 1385584                                                   NaN
# 1385585     Division of Pediatric Surgery, College of Phys...
# 1385589                        Johns Hopkins Oncology Center.
#
#                                                           AID  \
# Unnamed: 0
# 6           S1936-8798(22)01545-X [pii];10.1016/j.jcin.202...
# 8           S1936-8798(22)01544-8 [pii];10.1016/j.jcin.202...
# 13          S2405-500X(22)00583-7 [pii];10.1016/j.jacep.20...
# 15          S2589-7500(22)00150-9 [pii];10.1016/S2589-7500...
# 16          S1471-4914(22)00202-7 [pii];10.1016/j.molmed.2...
# ...                                                       ...
# 1385557                    10.1371/journal.pbio.0000069 [doi]
# 1385576                    10.1371/journal.pbio.0000020 [doi]
# 1385584                          10.15585/mmwr.mm6945a7 [doi]
# 1385585                                                   NaN
# 1385589                                                   NaN
#
#                                                            AU AUID  \
# Unnamed: 0
# 6                                          Dangas G;Nicolas J  NaN
# 8           Naganuma T;Panoulas VF;Onishi H;Kawamoto H;Nak...  NaN
# 13          Holmstrom L;Salmasi S;Chugh H;Uy-Evanado A;Sor...  NaN
# 15          Staessen JA;Wendt R;Yu YL;Kalbitz S;Thijs L;Si...  NaN
# 16                               Batista LFZ;Dokal I;Parker R  NaN
# ...                                                       ...  ...
# 1385557     Styrkarsdottir U;Cazier JB;Kong A;Rolfsson O;L...  NaN
# 1385576     Barroso I;Luan J;Middelberg RP;Harding AH;Fran...  NaN
# 1385584     Chard AN;Gacic-Dobo M;Diallo MS;Sodha SV;Walla...  NaN
# 1385585                                              Cooper A  NaN
# 1385589                               Grossman SA;Lossignol D  NaN
#
#                                                           FAU  \
# Unnamed: 0
# 6                               Dangas, George;Nicolas, Johny
# 8           Naganuma, Toru;Panoulas, Vasileios F;Onishi, H...
# 13          Holmstrom, Lauri;Salmasi, Shiva;Chugh, Harpriy...
# 15          Staessen, Jan A;Wendt, Ralph;Yu, Yu-Ling;Kalbi...
# 16             Batista, Luis F Z;Dokal, Inderjeet;Parker, Roy
# ...                                                       ...
# 1385557     Styrkarsdottir, Unnur;Cazier, Jean-Baptiste;Ko...
# 1385576     Barroso, Ines;Luan, Jian'an;Middelberg, Rita P...
# 1385584     Chard, Anna N;Gacic-Dobo, Marta;Diallo, Mamado...
# 1385585                                             Cooper, A
# 1385589                            Grossman, S A;Lossignol, D
#
#                                                          COIS         DEP  \
# Unnamed: 0
# 6           Funding Support and Author Disclosures Dr Geor...  20220822.0
# 8           Funding Support and Author Disclosures Dr. Tor...  20220824.0
# 13          Funding Support and Author Disclosures This wo...  20220829.0
# 15          Declaration of interests Harald Mischak is the...  20220831.0
# 16          Declaration of interests Roy Parker is a found...  20220831.0
# ...                                                       ...         ...
# 1385557     The authors have declared that conflicts of in...  20031103.0
# 1385576     Portions of the research were supported by Inc...  20031013.0
# 1385584     All authors have completed and submitted the I...  20201113.0
# 1385585     Dr. Justice reports no conflict of interest. D...         NaN
# 1385589     disclosures M. Loreto Yanez and Julie Miller h...         NaN
#
#                      DP                                           JT  \
# Unnamed: 0
# 6           2022 Aug 22           JACC. Cardiovascular interventions
# 8           2022 Aug 24           JACC. Cardiovascular interventions
# 13          2022 Aug 29             JACC. Clinical electrophysiology
# 15          2022 Aug 31                   The Lancet. Digital health
# 16          2022 Aug 31                 Trends in molecular medicine
# ...                 ...                                          ...
# 1385557        2003 Dec                                 PLoS biology
# 1385576        2003 Oct                                 PLoS biology
# 1385584     2020 Nov 13  MMWR. Morbidity and mortality weekly report
# 1385585        1995 Nov                Seminars in pediatric surgery
# 1385589        1990 Apr              Oncology (Williston Park, N.Y.)
#
#                    PMC                                                NER  \
# Unnamed: 0
# 6                  NaN                                  ['ORG', 'PERSON']
# 8                  NaN                                  ['PERSON', 'ORG']
# 13                 NaN  ['ORG', 'ORG', 'NORP', 'PERSON', 'ORG', 'ORG',...
# 15                 NaN  ['ORG', 'GPE', 'GPE', 'PERSON', 'ORG', 'ORG', ...
# 16                 NaN                                     ['ORG', 'ORG']
# ...                ...                                                ...
# 1385557      PMC270020                       ['ORG', 'GPE', 'ORG', 'ORG']
# 1385576      PMC212698                    ['ORG', 'PERSON', 'ORG', 'ORG']
# 1385584     PMC7660669                                            ['ORG']
# 1385585            NaN  ['PERSON', 'PERSON', 'ORG', 'ORG', 'ORG', 'ORG...
# 1385589     PMC5166582                               ['PERSON', 'PERSON']
#
#                       Ent                                 Tokenized Sentence  \
# Unnamed: 0
# 6           Entity Exists  ['Funding Support and Author Disclosures Dr Da...
# 8           Entity Exists  ['Funding Support and Author Disclosures Dr. N...
# 13          Entity Exists  ['Funding Support and Author Disclosures This ...
# 15          Entity Exists  ['Declaration of interests HM is the co-founde...
# 16          Entity Exists  ['Declaration of interests R.P.', 'is a founde...
# ...                   ...                                                ...
# 1385557     Entity Exists  ['The authors have declared that conflicts of ...
# 1385576     Entity Exists  ['Portions of the research were supported by I...
# 1385584     Entity Exists  ['All authors have completed and submitted the...
# 1385585     Entity Exists  ['Dr. Justice reports no conflict of interest....
# 1385589     Entity Exists  ['disclosures M. Loreto Yanez and Julie Miller...
#
#                                                     is_entity check_entity  \
# Unnamed: 0
# 6                                       [['ORG'], ['PERSON']]    Not empty
# 8                                     [['PERSON', 'ORG'], []]    Not empty
# 13          [['ORG', 'ORG', 'NORP'], [], ['ORG', 'ORG', 'O...    Not empty
# 15          [['ORG', 'GPE', 'GPE'], ['PERSON', 'ORG'], ['O...    Not empty
# 16                                     [['ORG'], ['ORG'], []]    Not empty
# ...                                                       ...          ...
# 1385557                  [[], ['ORG'], ['GPE', 'ORG', 'ORG']]    Not empty
# 1385576           [['ORG', 'PERSON'], [], [], ['ORG', 'ORG']]    Not empty
# 1385584                                         [['ORG'], []]    Not empty
# 1385585     [['PERSON'], ['PERSON', 'ORG', 'ORG', 'ORG', '...    Not empty
# 1385589                                [['PERSON', 'PERSON']]    Not empty
#
#                                                           LAU
# Unnamed: 0
# 6           [['George Dangas', 'George D', 'George D.', 'G...
# 8           [['Toru Naganuma', 'Toru N', 'Toru N.', 'TN', ...
# 13          [['Lauri Holmstrom', 'Lauri H', 'Lauri H.', 'L...
# 15          [['Jan Staessen', 'Jan S', 'Jan S.', 'Jan A St...
# 16          [['Luis Batista', 'Luis B', 'Luis B.', 'Luis F...
# ...                                                       ...
# 1385557     [['Unnur Styrkarsdottir', 'Unnur S', 'Unnur S....
# 1385576     [['Ines Barroso', 'Ines B', 'Ines B.', 'IB', '...
# 1385584     [['Anna Chard', 'Anna C', 'Anna C.', 'Anna N C...
# 1385585     [['A Cooper', 'A C', 'A C.', 'AC', 'A.C.', 'A ...
# 1385589     [['S Grossman', 'S G', 'S G.', 'S A Grossman',...
#
# [230806 rows x 19 columns]

# %%
#CALLING SPACY ON THIS DATA

# %%
import spacy
spacy_nlp = spacy.load('en_core_web_sm')

# %%
def show_entities(doc):
  flag = False
  t = []
  if doc.ents:
    for ent in doc.ents:
      if ent.label_ == "ORG":
        t.append(ent.text)
        flag = True
    if not flag:
      print('No named entities found.')
    return t

# %%
df.loc[15, 'COIS']
# Out:
# 'Declaration of interests Harald Mischak is the co-founder and co-owner of Mosaiques-Diagnostiques (Hannover, Germany). Jan A. Staessen and Julia Raad are employees of Mosaiques-Diagnostics. Harald D. Rupprecht received consulting fees and honoraria for presentations from Alexion, AstraZeneca, and Bristol-Myers-Squibb. All other authors declare no competing interests.'

# %%
show_entities(spacy_nlp(df.loc[15, 'COIS']))
# Out:
# ['Mosaiques-Diagnostiques',
#  'Mosaiques-Diagnostics',
#  'Alexion',
#  'AstraZeneca',
#  'Bristol-Myers-Squibb']

# %%
show_entities(spacy_nlp("Funding Support and Author Disclosures Dr. Naganuma is a clinical proctor of transcatheter aortic valve replacement for Edwards Lifesciences. All other authors have reported that they have no relationships relevant to the contents of this paper to disclose."))
# Out:
# ['Edwards Lifesciences']

# %%
show_entities(spacy_nlp('Funding Support and Author Disclosures This work was funded, in part, by National Institutes of Health, National Heart Lung and Blood Institute grants R01HL145675  and R01HL147358 to Dr Chugh. Dr Chugh holds the Pauline and Harold Price Chair in Cardiac Electrophysiology at Cedars-Sinai. Dr Holmstrom was supported by the Sigrid Juselius Foundation, Finnish Cultural Foundation, Instrumentarium Science  Foundation, Orion Research Foundation, and Paavo Nurmi Foundation. The funding sources had no involvement in the preparation of this work or the decision to submit for publication. All other authors have reported that they have no relationships relevant to the contents of this paper to disclose.'))
# Out:
# ['National Institutes of Health',
#  'Blood Institute',
#  'Cedars-Sinai',
#  'the Sigrid Juselius Foundation',
#  'Finnish Cultural Foundation',
#  'Instrumentarium Science  Foundation',
#  'Orion Research Foundation',
#  'Paavo Nurmi Foundation']

# %%
#CALLING BERT NER ON THIS DATA

# %%
nlp = pipeline("ner", model=model, tokenizer=tokenizer)

# %%
test = nlp("Funding Support and Author Disclosures This work was funded, in part, by National Institutes of Health, National Heart Lung and Blood Institute grants R01HL145675  and R01HL147358 to Dr Chugh. Dr Chugh holds the Pauline and Harold Price Chair in Cardiac Electrophysiology at Cedars-Sinai. Dr Holmstrom was supported by the Sigrid Juselius Foundation, Finnish Cultural Foundation, Instrumentarium Science  Foundation, Orion Research Foundation, and Paavo Nurmi Foundation. The funding sources had no involvement in the preparation of this work or the decision to submit for publication. All other authors have reported that they have no relationships relevant to the contents of this paper to disclose.")
test
# Out:
# [{'entity': 'B-ORG',
#   'score': 0.9969451,
#   'index': 17,
#   'word': 'National',
#   'start': 73,
#   'end': 81},
#  {'entity': 'I-ORG',
#   'score': 0.9972063,
#   'index': 18,
#   'word': 'Institutes',
#   'start': 82,
#   'end': 92},
#  {'entity': 'I-ORG',
#   'score': 0.9979929,
#   'index': 19,
#   'word': 'of',
#   'start': 93,
#   'end': 95},
#  {'entity': 'I-ORG',
#   'score': 0.9972384,
#   'index': 20,
#   'word': 'Health',
#   'start': 96,
#   'end': 102},
#  {'entity': 'B-ORG',
#   'score': 0.997106,
#   'index': 22,
#   'word': 'National',
#   'start': 104,
#   'end': 112},
#  {'entity': 'I-ORG',
#   'score': 0.9953945,
#   'index': 23,
#   'word': 'Heart',
#   'start': 113,
#   'end': 118},
#  {'entity': 'I-ORG',
#   'score': 0.9976278,
#   'index': 24,
#   'word': 'Lu',
#   'start': 119,
#   'end': 121},
#  {'entity': 'I-ORG',
#   'score': 0.98770535,
#   'index': 25,
#   'word': '##ng',
#   'start': 121,
#   'end': 123},
#  {'entity': 'I-ORG',
#   'score': 0.9943863,
#   'index': 26,
#   'word': 'and',
#   'start': 124,
#   'end': 127},
#  {'entity': 'I-ORG',
#   'score': 0.99565744,
#   'index': 27,
#   'word': 'Blood',
#   'start': 128,
#   'end': 133},
#  {'entity': 'I-ORG',
#   'score': 0.9963658,
#   'index': 28,
#   'word': 'Institute',
#   'start': 134,
#   'end': 143},
#  {'entity': 'B-PER',
#   'score': 0.99784493,
#   'index': 47,
#   'word': 'Chu',
#   'start': 186,
#   'end': 189},
#  {'entity': 'I-PER',
#   'score': 0.95312876,
#   'index': 48,
#   'word': '##gh',
#   'start': 189,
#   'end': 191},
#  {'entity': 'B-PER',
#   'score': 0.99777776,
#   'index': 51,
#   'word': 'Chu',
#   'start': 196,
#   'end': 199},
#  {'entity': 'I-PER',
#   'score': 0.9603552,
#   'index': 52,
#   'word': '##gh',
#   'start': 199,
#   'end': 201},
#  {'entity': 'B-PER',
#   'score': 0.99341846,
#   'index': 55,
#   'word': 'Pauline',
#   'start': 212,
#   'end': 219},
#  {'entity': 'I-PER',
#   'score': 0.682516,
#   'index': 56,
#   'word': 'and',
#   'start': 220,
#   'end': 223},
#  {'entity': 'B-PER',
#   'score': 0.97606045,
#   'index': 57,
#   'word': 'Harold',
#   'start': 224,
#   'end': 230},
#  {'entity': 'I-PER',
#   'score': 0.99774396,
#   'index': 58,
#   'word': 'Price',
#   'start': 231,
#   'end': 236},
#  {'entity': 'I-MISC',
#   'score': 0.70129573,
#   'index': 62,
#   'word': '##iac',
#   'start': 250,
#   'end': 253},
#  {'entity': 'I-ORG',
#   'score': 0.47892615,
#   'index': 63,
#   'word': 'El',
#   'start': 254,
#   'end': 256},
#  {'entity': 'I-MISC',
#   'score': 0.48625654,
#   'index': 64,
#   'word': '##ec',
#   'start': 256,
#   'end': 258},
#  {'entity': 'I-MISC',
#   'score': 0.78651065,
#   'index': 65,
#   'word': '##tro',
#   'start': 258,
#   'end': 261},
#  {'entity': 'I-MISC',
#   'score': 0.33844674,
#   'index': 66,
#   'word': '##phy',
#   'start': 261,
#   'end': 264},
#  {'entity': 'I-MISC',
#   'score': 0.67958564,
#   'index': 67,
#   'word': '##sio',
#   'start': 264,
#   'end': 267},
#  {'entity': 'I-MISC',
#   'score': 0.4548467,
#   'index': 68,
#   'word': '##logy',
#   'start': 267,
#   'end': 271},
#  {'entity': 'B-ORG',
#   'score': 0.5932804,
#   'index': 70,
#   'word': 'Cedar',
#   'start': 275,
#   'end': 280},
#  {'entity': 'I-ORG',
#   'score': 0.52318376,
#   'index': 71,
#   'word': '##s',
#   'start': 280,
#   'end': 281},
#  {'entity': 'I-ORG',
#   'score': 0.50984704,
#   'index': 72,
#   'word': '-',
#   'start': 281,
#   'end': 282},
#  {'entity': 'I-ORG',
#   'score': 0.5534811,
#   'index': 73,
#   'word': 'Sinai',
#   'start': 282,
#   'end': 287},
#  {'entity': 'B-PER',
#   'score': 0.99910945,
#   'index': 76,
#   'word': 'Ho',
#   'start': 292,
#   'end': 294},
#  {'entity': 'I-PER',
#   'score': 0.9397136,
#   'index': 77,
#   'word': '##lm',
#   'start': 294,
#   'end': 296},
#  {'entity': 'I-PER',
#   'score': 0.9206048,
#   'index': 78,
#   'word': '##strom',
#   'start': 296,
#   'end': 301},
#  {'entity': 'B-ORG',
#   'score': 0.9975986,
#   'index': 83,
#   'word': 'Si',
#   'start': 323,
#   'end': 325},
#  {'entity': 'I-ORG',
#   'score': 0.9930808,
#   'index': 85,
#   'word': '##rid',
#   'start': 326,
#   'end': 329},
#  {'entity': 'I-ORG',
#   'score': 0.99544394,
#   'index': 86,
#   'word': 'Ju',
#   'start': 330,
#   'end': 332},
#  {'entity': 'I-ORG',
#   'score': 0.9872574,
#   'index': 87,
#   'word': '##sel',
#   'start': 332,
#   'end': 335},
#  {'entity': 'I-ORG',
#   'score': 0.9955928,
#   'index': 88,
#   'word': '##ius',
#   'start': 335,
#   'end': 338},
#  {'entity': 'I-ORG',
#   'score': 0.9976133,
#   'index': 89,
#   'word': 'Foundation',
#   'start': 339,
#   'end': 349},
#  {'entity': 'B-ORG',
#   'score': 0.9951776,
#   'index': 91,
#   'word': 'Finnish',
#   'start': 351,
#   'end': 358},
#  {'entity': 'I-ORG',
#   'score': 0.9944443,
#   'index': 92,
#   'word': 'Cultural',
#   'start': 359,
#   'end': 367},
#  {'entity': 'I-ORG',
#   'score': 0.9971246,
#   'index': 93,
#   'word': 'Foundation',
#   'start': 368,
#   'end': 378},
#  {'entity': 'B-ORG',
#   'score': 0.9989281,
#   'index': 95,
#   'word': 'In',
#   'start': 380,
#   'end': 382},
#  {'entity': 'I-ORG',
#   'score': 0.99029714,
#   'index': 96,
#   'word': '##st',
#   'start': 382,
#   'end': 384},
#  {'entity': 'I-ORG',
#   'score': 0.9738299,
#   'index': 98,
#   'word': '##ent',
#   'start': 387,
#   'end': 390},
#  {'entity': 'I-ORG',
#   'score': 0.99764246,
#   'index': 99,
#   'word': '##arium',
#   'start': 390,
#   'end': 395},
#  {'entity': 'I-ORG',
#   'score': 0.99861586,
#   'index': 100,
#   'word': 'Science',
#   'start': 396,
#   'end': 403},
#  {'entity': 'I-ORG',
#   'score': 0.99861014,
#   'index': 101,
#   'word': 'Foundation',
#   'start': 405,
#   'end': 415},
#  {'entity': 'B-ORG',
#   'score': 0.99913317,
#   'index': 103,
#   'word': 'Orion',
#   'start': 417,
#   'end': 422},
#  {'entity': 'I-ORG',
#   'score': 0.9990957,
#   'index': 104,
#   'word': 'Research',
#   'start': 423,
#   'end': 431},
#  {'entity': 'I-ORG',
#   'score': 0.99878806,
#   'index': 105,
#   'word': 'Foundation',
#   'start': 432,
#   'end': 442},
#  {'entity': 'B-ORG',
#   'score': 0.9977695,
#   'index': 108,
#   'word': 'Pa',
#   'start': 448,
#   'end': 450},
#  {'entity': 'I-ORG',
#   'score': 0.983322,
#   'index': 109,
#   'word': '##av',
#   'start': 450,
#   'end': 452},
#  {'entity': 'I-ORG',
#   'score': 0.9918503,
#   'index': 110,
#   'word': '##o',
#   'start': 452,
#   'end': 453},
#  {'entity': 'I-ORG',
#   'score': 0.99790925,
#   'index': 111,
#   'word': 'N',
#   'start': 454,
#   'end': 455},
#  {'entity': 'I-ORG',
#   'score': 0.9788576,
#   'index': 113,
#   'word': '##mi',
#   'start': 457,
#   'end': 459},
#  {'entity': 'I-ORG',
#   'score': 0.9977362,
#   'index': 114,
#   'word': 'Foundation',
#   'start': 460,
#   'end': 470}]

# %%
def basic_bert(doc):
  t = []
  c = 0
  
  for item in doc:
    if item['score'] > 0.95 and item['entity'] == 'B-ORG':
      t.append(item['word'])
      c += 1
    elif item['score'] > 0.95 and item['entity'] == "I-ORG" and '##' in item['word']:
      t[c-1] += item['word'][2:]
    elif item['score'] > 0.95 and item['entity'] == "I-ORG":
      t[c-1] += " " + item['word'] 

  for i in range(len(t)):
    t[i] = t[i].strip()
    
  return t

# %%
test = nlp("Funding Support and Author Disclosures This work was funded, in part, by National Institutes of Health, National Heart Lung and Blood Institute grants R01HL145675  and R01HL147358 to Dr Chugh. Dr Chugh holds the Pauline and Harold Price Chair in Cardiac Electrophysiology at Cedars-Sinai. Dr Holmstrom was supported by the Sigrid Juselius Foundation, Finnish Cultural Foundation, Instrumentarium Science  Foundation, Orion Research Foundation, and Paavo Nurmi Foundation. The funding sources had no involvement in the preparation of this work or the decision to submit for publication. All other authors have reported that they have no relationships relevant to the contents of this paper to disclose.")
t = basic_bert(test)
print(t)
# Out:
# ['National Institutes of Health', 'National Heart Lung and Blood Institute', 'Sirid Juselius Foundation', 'Finnish Cultural Foundation', 'Instentarium Science Foundation', 'Orion Research Foundation', 'Paavo Nmi Foundation']

# %%
df.loc[15, 'COIS']
# Out:
# 'Declaration of interests Harald Mischak is the co-founder and co-owner of Mosaiques-Diagnostiques (Hannover, Germany). Jan A. Staessen and Julia Raad are employees of Mosaiques-Diagnostics. Harald D. Rupprecht received consulting fees and honoraria for presentations from Alexion, AstraZeneca, and Bristol-Myers-Squibb. All other authors declare no competing interests.'

# %%
basic_bert(nlp(df.loc[15, 'COIS']))
# Out:
# ['Mosaiques - Diagnostiques',
#  'Mosaiques - Diagnostics',
#  'Alexion',
#  'AstraZeneca',
#  'Bristol - Myers - Squibb']

# %%
basic_bert(nlp('Declaration of interests HM is the co-founder and co-owner of Mosaiques-Diagnostiques (Hannover, Germany). JS and JR are employees of Mosaiques-Diagnostics. HDR received consulting fees and honoraria for presentations from Alexion, AstraZeneca, and Bristol-Myers-Squibb. All other authors declare no competing interests.'))
# Out:
# ['HM',
#  'Mosaiques - Diagnostiques',
#  'J',
#  'JR',
#  'Mosaiques - Diagnostics',
#  'HDR',
#  'Alexion',
#  'AstraZeneca',
#  'Bristol - Myers - Squibb']
